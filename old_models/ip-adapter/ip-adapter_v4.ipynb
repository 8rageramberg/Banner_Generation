# %%
# Out:
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 18.82it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 32
#      26 pipe = AutoPipelineForText2Image.from_pretrained(
#      27     model_id,
#      28     torch_dtype=dtype
#      29 ).to(device)
#      31 # === Load IP-Adapter ===
# ---> 32 pipe.load_ip_adapter(ip_adapter_path, subfolder=subfolder, weight_name=ip_weights)
#      33 pipe.set_ip_adapter_scale(adapter_scale)
#      35 # 🛑 Disable NSFW checker properly
#
# File ~/opt/miniconda3/envs/bannergen/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# ...
